# %% [markdown]
# # Introduction
#
# This notebook outlines how to build a recommendation system using SageMaker's Factorization Machines (FM). The main goal is to showcase how to extend FM model to predict top "X" recommendations using SageMaker's KNN and Batch Transform.
#
# There are four parts to this notebook:
#
# 1. Building a FM Model
# 2. Repackaging FM Model to fit a KNN Model
# 3. Building a KNN model
# 4. Running Batch Transform for predicting top "X" items

# %% [markdown]
# ## Part 1 - Building a FM Model using movie lens dataset
#
# Julien Simon has written a fantastic blog about how to build a FM model using SageMaker with detailed explanation. Please see the links below for more information. In this part, I utilized his code for the most part to have continutity for performing additional steps.
#
# Source - https://aws.amazon.com/blogs/machine-learning/build-a-movie-recommender-with-factorization-machines-on-amazon-sagemaker/

# %%
import sagemaker
import sagemaker.amazon.common as smac
from sagemaker import get_execution_role
from sagemaker.predictor import json_deserializer
from sagemaker.amazon.amazon_estimator import get_image_uri
import numpy as np
from scipy.sparse import lil_matrix
import pandas as pd
import boto3, io, os
import multiprocessing
from multiprocessing import Pool

# %% [markdown]
# ### Download movie rating data from movie lens

# %%
#download data
#!wget http://files.grouplens.org/datasets/movielens/ml-100k.zip
#!unzip -o ml-100k.zip

# %pwd
# Out:
# u'/home/ec2-user/SageMaker/MovieRecommender/Notebook'

# %% [markdown]
# ### Shuffle the data

# %%
# %cd ml-latest-small
#%cd ml-20m
# !shuf ua.base -o ua.base.shuffled
# Out:
# /home/ec2-user/SageMaker/MovieRecommender/Notebook/ml-latest-small

# %% [markdown]
# ### Load Training Data

# %%
user_movie_ratings_train = pd.read_csv('ua.base.shuffled', sep=',', header=0, index_col=False, 
                 names=['user_id' , 'movie_id' , 'rating'])
user_movie_ratings_train.head(5)
# Out:
#    user_id  movie_id  rating
# 0        6       736     5.0
# 1       42       648     5.0
# 2      409      3590     2.0
# 3      156      3089     4.0
# 4      294      2134     3.0

# %% [markdown]
# ### Load Test Data

# %%
user_movie_ratings_test = pd.read_csv('ua.test', sep=',', header=0, index_col=False, 
                 names=['user_id' , 'movie_id' , 'rating'])
user_movie_ratings_test.head(5)
# Out:
#    user_id  movie_id  rating
# 0        1         3     4.0
# 1        1         6     4.0
# 2        1        47     5.0
# 3        1        50     5.0
# 4        1        70     3.0

# %%
nb_users= user_movie_ratings_train['user_id'].max()
nb_movies=user_movie_ratings_train['movie_id'].max()
nb_features=nb_users+nb_movies
nb_ratings_test=len(user_movie_ratings_test.index)
nb_ratings_train=len(user_movie_ratings_train.index)
print " # of users: ", nb_users
print " # of movies: ", nb_movies
print " Training Count: ", nb_ratings_train
print " Test Count: ", nb_ratings_test
print " Features (# of users + # of movies): ", nb_features
# Out:
#  # of users:  610
#  # of movies:  193609
#  Training Count:  94735
#  Test Count:  6099
#  Features (# of users + # of movies):  194219

# %% [markdown]
# ### FM Input
#
# Input to FM is a one-hot encoded sparse matrix. Only ratings 4 and above are considered for the model. We will be ignoring ratings 3 and below.

# %%
# def transformRow(row):
#     cur_row = []
#     if int(row[2]) >= 4:
#         cur_row.append(1)
#     else:
#         cur_row.append(0)
        
#      matrix[line,row[0]-1] = 1
    
#      matrix[line, nb_users+(row[1]-1)] = 1   
    
#     return cur_row

# def transformMatrix(row):
#     matrix[line,row[0]-1] = 1
#     matrix[line, nb_users+(row[1]-1)] = 1
#     return matrix

def loadDataset(df, lines, columns):
    # Features are one-hot encoded in a sparse matrix
    X = lil_matrix((lines, columns)).astype('float32')
    # Labels are stored in a vector
    Y = []
    
#     yPool = Pool(processes=multiprocessing.cpu_count())
#     Y = yPool.map(transformRow, df.values())
#     yPool.close() 
#     yPool.join()
    
#     xPool = Pool(processes=multiprocessing.cpu_count())
#     Y = xPool.map(transformRow, df.values())
#     xPool.close() 
#     xPool.join()
    
    line=0
    for index, row in df.iterrows():
            if int(row['rating']) >= 4:
                Y.append(1)
            else:
                Y.append(0)

    for index, row in df.iterrows():
        X[line,row['user_id']-1] = 1
        X[line, nb_users+(row['movie_id']-1)] = 1
        line=line+1

    Y=np.array(Y).astype('float32')            
    return X,Y


X_train, Y_train = loadDataset(user_movie_ratings_train, nb_ratings_train, nb_features)
X_test, Y_test = loadDataset(user_movie_ratings_test, nb_ratings_test, nb_features)

# %%
print(X_train.shape)
print(Y_train.shape)
assert X_train.shape == (nb_ratings_train, nb_features)
assert Y_train.shape == (nb_ratings_train, )
zero_labels = np.count_nonzero(Y_train)
print("Training labels: %d zeros, %d ones" % (zero_labels, nb_ratings_train-zero_labels))

print(X_test.shape)
print(Y_test.shape)
assert X_test.shape  == (nb_ratings_test, nb_features)
assert Y_test.shape  == (nb_ratings_test, )
zero_labels = np.count_nonzero(Y_test)
print("Test labels: %d zeros, %d ones" % (zero_labels, nb_ratings_test-zero_labels))
# Out:
# (94735, 194219)
# (94735,)
# Training labels: 45037 zeros, 49698 ones
# (6099, 194219)
# (6099,)
# Test labels: 3542 zeros, 2557 ones

# %% [markdown]
# ### Convert to Protobuf format for saving to S3

# %%
#Change this value to your own bucket name
bucket = 'movie-recommender-josh-krishna'
prefix = 'fm'

train_key      = 'train.protobuf'
train_prefix   = '{}/{}'.format(prefix, 'train')

test_key       = 'test.protobuf'
test_prefix    = '{}/{}'.format(prefix, 'test')

output_prefix  = 's3://{}/{}/output'.format(bucket, prefix)

# %%
def writeDatasetToProtobuf(X, bucket, prefix, key, d_type, Y=None):
    buf = io.BytesIO()
    if d_type == "sparse":
        smac.write_spmatrix_to_sparse_tensor(buf, X, labels=Y)
    else:
        smac.write_numpy_to_dense_tensor(buf, X, labels=Y)
        
    buf.seek(0)
    obj = '{}/{}'.format(prefix, key)
    boto3.resource('s3').Bucket(bucket).Object(obj).upload_fileobj(buf)
    return 's3://{}/{}'.format(bucket,obj)
    
fm_train_data_path = writeDatasetToProtobuf(X_train, bucket, train_prefix, train_key, "sparse", Y_train)    
fm_test_data_path  = writeDatasetToProtobuf(X_test, bucket, test_prefix, test_key, "sparse", Y_test)    
  
print "Training data S3 path: ",fm_train_data_path
print "Test data S3 path: ",fm_test_data_path
print "FM model output S3 path: {}".format(output_prefix)
# Out:
# Training data S3 path:  s3://movie-recommender-josh-krishna/fm/train/train.protobuf
# Test data S3 path:  s3://movie-recommender-josh-krishna/fm/test/test.protobuf
# FM model output S3 path: s3://movie-recommender-josh-krishna/fm/output

# %% [markdown]
# ### Run training job
#
# You can play around with the hyper parameters until you are happy with the prediction. For this dataset and hyper parameters configuration, after 100 epochs, test accuracy was around 70% on average and the F1 score (a typical metric for a binary classifier) was around 0.74 (1 indicates a perfect classifier). Not great, but you can fine tune the model further.

# %%
instance_type='ml.m5.large'
fm = sagemaker.estimator.Estimator(get_image_uri(boto3.Session().region_name, "factorization-machines"),
                                   get_execution_role(), 
                                   train_instance_count=1, 
                                   train_instance_type=instance_type,
                                   output_path=output_prefix,
                                   sagemaker_session=sagemaker.Session())

fm.set_hyperparameters(feature_dim=nb_features,
                      predictor_type='binary_classifier',
                      mini_batch_size=1000,
                      num_factors=64,
                      epochs=100)

fm.fit({'train': fm_train_data_path, 'test': fm_test_data_path})
# Out:
# 2019-06-13 18:16:18 Starting - Starting the training job...
# 2019-06-13 18:16:25 Starting - Launching requested ML instances.........
# 2019-06-13 18:17:59 Starting - Preparing the instances for training......
# 2019-06-13 18:19:02 Downloading - Downloading input data...
# 2019-06-13 18:19:49 Training - Downloading the training image..
# Docker entrypoint called with argument(s): train
# [06/13/2019 18:19:52 INFO 140082306389824] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'factors_lr': u'0.0001', u'linear_init_sigma': u'0.01', u'epochs': 1, u'_wd': u'1.0', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'factors_init_sigma': u'0.001', u'_log_level': u'info', u'bias_init_method': u'normal', u'linear_init_method': u'normal', u'linear_lr': u'0.001', u'factors_init_method': u'normal', u'_tuning_objective_metric': u'', u'bias_wd': u'0.01', u'use_linear': u'true', u'bias_lr': u'0.1', u'mini_batch_size': u'1000', u'_use_full_symbolic': u'true', u'batch_metrics_publish_interval': u'500', u'bias_init_sigma': u'0.01', u'_num_gpus': u'auto', u'_data_format': u'record', u'factors_wd': u'0.00001', u'linear_wd': u'0.001', u'_kvstore': u'auto', u'_learning_rate': u'1.0', u'_optimizer': u'adam'}
# [06/13/2019 18:19:52 INFO 140082306389824] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'epochs': u'100', u'feature_dim': u'194219', u'mini_batch_size': u'1000', u'predictor_type': u'binary_classifier', u'num_factors': u'64'}
# [06/13/2019 18:19:52 INFO 140082306389824] Final configuration: {u'factors_lr': u'0.0001', u'linear_init_sigma': u'0.01', u'epochs': u'100', u'feature_dim': u'194219', u'num_factors': u'64', u'_wd': u'1.0', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'factors_init_sigma': u'0.001', u'_log_level': u'info', u'bias_init_method': u'normal', u'linear_init_method': u'normal', u'linear_lr': u'0.001', u'factors_init_method': u'normal', u'_tuning_objective_metric': u'', u'bias_wd': u'0.01', u'use_linear': u'true', u'bias_lr': u'0.1', u'mini_batch_size': u'1000', u'_use_full_symbolic': u'true', u'batch_metrics_publish_interval': u'500', u'predictor_type': u'binary_classifier', u'bias_init_sigma': u'0.01', u'_num_gpus': u'auto', u'_data_format': u'record', u'factors_wd': u'0.00001', u'linear_wd': u'0.001', u'_kvstore': u'auto', u'_learning_rate': u'1.0', u'_optimizer': u'adam'}
# [06/13/2019 18:19:52 WARNING 140082306389824] Loggers have already been setup.
# Process 1 is a worker.
# [06/13/2019 18:19:52 INFO 140082306389824] Using default worker.
# [2019-06-13 18:19:52.953] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2019-06-13 18:19:52.975] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 31, "num_examples": 1, "num_bytes": 64000}
# [06/13/2019 18:19:53 INFO 140082306389824] nvidia-smi took: 0.0251531600952 secs to identify 0 gpus
# [06/13/2019 18:19:53 INFO 140082306389824] Number of GPUs being used: 0
# [06/13/2019 18:19:53 INFO 140082306389824] [Sparse network] Building a sparse network.
# [06/13/2019 18:19:53 INFO 140082306389824] Create Store: local
# #metrics {"Metrics": {"initialize.time": {"count": 1, "max": 49.870967864990234, "sum": 49.870967864990234, "min": 49.870967864990234}}, "EndTime": 1560449993.020955, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560449992.944286}
#
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 1000, "sum": 1000.0, "min": 1000}, "Max Records Seen Between Resets": {"count": 1, "max": 1000, "sum": 1000.0, "min": 1000}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1560449993.02122, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560449993.021172}
#
# [18:19:53] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.1.x.201496.0/RHEL5_64/generic-flavor/src/src/kvstore/./kvstore_local.h:280: Warning: non-default weights detected during kvstore pull. This call has been ignored. Please make sure to use row_sparse_pull with row_ids.
# [18:19:53] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.1.x.201496.0/RHEL5_64/generic-flavor/src/src/kvstore/./kvstore_local.h:280: Warning: non-default weights detected during kvstore pull. This call has been ignored. Please make sure to use row_sparse_pull with row_ids.
# [06/13/2019 18:19:53 INFO 140082306389824] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_classification_accuracy <score>=0.5
# [06/13/2019 18:19:53 INFO 140082306389824] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_classification_cross_entropy <loss>=0.69352130127
# [06/13/2019 18:19:53 INFO 140082306389824] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_f_1.000 <score>=0.651810584958
# [2019-06-13 18:19:55.033] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 2, "duration": 1303, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:19:55 INFO 140082306389824] #quality_metric: host=algo-1, epoch=0, train binary_classification_accuracy <score>=0.544621052632
# [06/13/2019 18:19:55 INFO 140082306389824] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy <loss>=0.686353615851
# [06/13/2019 18:19:55 INFO 140082306389824] #quality_metric: host=algo-1, epoch=0, train binary_f_1.000 <score>=0.128663215775
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 100, "sum": 100.0, "min": 100}, "update.time": {"count": 1, "max": 2013.239860534668, "sum": 2013.239860534668, "min": 2013.239860534668}}, "EndTime": 1560449995.034689, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560449993.021027}
#
# [06/13/2019 18:19:55 INFO 140082306389824] #progress_metric: host=algo-1, completed 1 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 96, "sum": 96.0, "min": 96}, "Total Records Seen": {"count": 1, "max": 95735, "sum": 95735.0, "min": 95735}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1560449995.035395, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 0}, "StartTime": 1560449993.021415}
#
# [06/13/2019 18:19:55 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=47031.4357459 records/second
# [06/13/2019 18:19:55 INFO 140082306389824] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_classification_accuracy <score>=0.51
# [06/13/2019 18:19:55 INFO 140082306389824] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_classification_cross_entropy <loss>=0.683032470703
# [06/13/2019 18:19:55 INFO 140082306389824] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_f_1.000 <score>=0.0
# [2019-06-13 18:19:56.173] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 1135, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:19:56 INFO 140082306389824] #quality_metric: host=algo-1, epoch=1, train binary_classification_accuracy <score>=0.612389473684
# [06/13/2019 18:19:56 INFO 140082306389824] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy <loss>=0.674639758943
# [06/13/2019 18:19:56 INFO 140082306389824] #quality_metric: host=algo-1, epoch=1, train binary_f_1.000 <score>=0.402369552869
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1138.171911239624, "sum": 1138.171911239624, "min": 1138.171911239624}}, "EndTime": 1560449996.174625, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560449995.035075}
#
# [06/13/2019 18:19:56 INFO 140082306389824] #progress_metric: host=algo-1, completed 2 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 191, "sum": 191.0, "min": 191}, "Total Records Seen": {"count": 1, "max": 190470, "sum": 190470.0, "min": 190470}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1560449996.174966, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 1}, "StartTime": 1560449995.036419}
#
# [06/13/2019 18:19:56 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=83196.5502235 records/second
# [06/13/2019 18:19:56 INFO 140082306389824] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_classification_accuracy <score>=0.534
# [06/13/2019 18:19:56 INFO 140082306389824] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_classification_cross_entropy <loss>=0.672849975586
# [06/13/2019 18:19:56 INFO 140082306389824] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_f_1.000 <score>=0.103846153846
# [2019-06-13 18:19:57.365] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 1188, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:19:57 INFO 140082306389824] #quality_metric: host=algo-1, epoch=2, train binary_classification_accuracy <score>=0.656831578947
# [06/13/2019 18:19:57 INFO 140082306389824] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy <loss>=0.663789046438
# [06/13/2019 18:19:57 INFO 140082306389824] #quality_metric: host=algo-1, epoch=2, train binary_f_1.000 <score>=0.535446086325
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1190.580129623413, "sum": 1190.580129623413, "min": 1190.580129623413}}, "EndTime": 1560449997.366244, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560449996.174703}
#
# [06/13/2019 18:19:57 INFO 140082306389824] #progress_metric: host=algo-1, completed 3 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 286, "sum": 286.0, "min": 286}, "Total Records Seen": {"count": 1, "max": 285205, "sum": 285205.0, "min": 285205}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1560449997.366601, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 2}, "StartTime": 1560449996.175634}
#
# [06/13/2019 18:19:57 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=79535.9221974 records/second
# [06/13/2019 18:19:57 INFO 140082306389824] #quality_metric: host=algo-1, epoch=3, batch=0 train binary_classification_accuracy <score>=0.609
# [06/13/2019 18:19:57 INFO 140082306389824] #quality_metric: host=algo-1, epoch=3, batch=0 train binary_classification_cross_entropy <loss>=0.663197509766
# [06/13/2019 18:19:57 INFO 140082306389824] #quality_metric: host=algo-1, epoch=3, batch=0 train binary_f_1.000 <score>=0.37037037037
# [2019-06-13 18:19:58.777] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 1409, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:19:58 INFO 140082306389824] #quality_metric: host=algo-1, epoch=3, train binary_classification_accuracy <score>=0.682021052632
# [06/13/2019 18:19:58 INFO 140082306389824] #quality_metric: host=algo-1, epoch=3, train binary_classification_cross_entropy <loss>=0.653780320981
# [06/13/2019 18:19:58 INFO 140082306389824] #quality_metric: host=algo-1, epoch=3, train binary_f_1.000 <score>=0.599384648029
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1411.3531112670898, "sum": 1411.3531112670898, "min": 1411.3531112670898}}, "EndTime": 1560449998.778768, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560449997.366337}
#
# [06/13/2019 18:19:58 INFO 140082306389824] #progress_metric: host=algo-1, completed 4 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 381, "sum": 381.0, "min": 381}, "Total Records Seen": {"count": 1, "max": 379940, "sum": 379940.0, "min": 379940}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1560449998.779077, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 3}, "StartTime": 1560449997.367328}
#
# [06/13/2019 18:19:58 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=67099.2370107 records/second
# [06/13/2019 18:19:58 INFO 140082306389824] #quality_metric: host=algo-1, epoch=4, batch=0 train binary_classification_accuracy <score>=0.64
# [06/13/2019 18:19:58 INFO 140082306389824] #quality_metric: host=algo-1, epoch=4, batch=0 train binary_classification_cross_entropy <loss>=0.654152709961
# [06/13/2019 18:19:58 INFO 140082306389824] #quality_metric: host=algo-1, epoch=4, batch=0 train binary_f_1.000 <score>=0.485714285714
# [2019-06-13 18:20:00.297] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 10, "duration": 1516, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:20:00 INFO 140082306389824] #quality_metric: host=algo-1, epoch=4, train binary_classification_accuracy <score>=0.697063157895
# [06/13/2019 18:20:00 INFO 140082306389824] #quality_metric: host=algo-1, epoch=4, train binary_classification_cross_entropy <loss>=0.644438524748
# [06/13/2019 18:20:00 INFO 140082306389824] #quality_metric: host=algo-1, epoch=4, train binary_f_1.000 <score>=0.634724002691
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1518.8088417053223, "sum": 1518.8088417053223, "min": 1518.8088417053223}}, "EndTime": 1560450000.298587, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560449998.778845}
#
# [06/13/2019 18:20:00 INFO 140082306389824] #progress_metric: host=algo-1, completed 5 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 476, "sum": 476.0, "min": 476}, "Total Records Seen": {"count": 1, "max": 474675, "sum": 474675.0, "min": 474675}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1560450000.29913, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 4}, "StartTime": 1560449998.77973}
#
# [06/13/2019 18:20:00 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=62344.8451905 records/second
# [06/13/2019 18:20:00 INFO 140082306389824] #quality_metric: host=algo-1, epoch=5, batch=0 train binary_classification_accuracy <score>=0.658
# [06/13/2019 18:20:00 INFO 140082306389824] #quality_metric: host=algo-1, epoch=5, batch=0 train binary_classification_cross_entropy <loss>=0.645669311523
# [06/13/2019 18:20:00 INFO 140082306389824] #quality_metric: host=algo-1, epoch=5, batch=0 train binary_f_1.000 <score>=0.541554959786
# [2019-06-13 18:20:01.494] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 12, "duration": 1192, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:20:01 INFO 140082306389824] #quality_metric: host=algo-1, epoch=5, train binary_classification_accuracy <score>=0.707326315789
# [06/13/2019 18:20:01 INFO 140082306389824] #quality_metric: host=algo-1, epoch=5, train binary_classification_cross_entropy <loss>=0.635709662186
# [06/13/2019 18:20:01 INFO 140082306389824] #quality_metric: host=algo-1, epoch=5, train binary_f_1.000 <score>=0.656486286138
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1195.4739093780518, "sum": 1195.4739093780518, "min": 1195.4739093780518}}, "EndTime": 1560450001.495514, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450000.298775}
#
# [06/13/2019 18:20:01 INFO 140082306389824] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 571, "sum": 571.0, "min": 571}, "Total Records Seen": {"count": 1, "max": 569410, "sum": 569410.0, "min": 569410}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1560450001.495946, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 5}, "StartTime": 1560450000.300005}
#
# [06/13/2019 18:20:01 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=79204.5702822 records/second
# [06/13/2019 18:20:01 INFO 140082306389824] #quality_metric: host=algo-1, epoch=6, batch=0 train binary_classification_accuracy <score>=0.673
# [06/13/2019 18:20:01 INFO 140082306389824] #quality_metric: host=algo-1, epoch=6, batch=0 train binary_classification_cross_entropy <loss>=0.637716064453
# [06/13/2019 18:20:01 INFO 140082306389824] #quality_metric: host=algo-1, epoch=6, batch=0 train binary_f_1.000 <score>=0.585551330798
# [2019-06-13 18:20:02.674] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 14, "duration": 1176, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:20:02 INFO 140082306389824] #quality_metric: host=algo-1, epoch=6, train binary_classification_accuracy <score>=0.714042105263
# [06/13/2019 18:20:02 INFO 140082306389824] #quality_metric: host=algo-1, epoch=6, train binary_classification_cross_entropy <loss>=0.627554280813
# [06/13/2019 18:20:02 INFO 140082306389824] #quality_metric: host=algo-1, epoch=6, train binary_f_1.000 <score>=0.670123372839
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1178.765058517456, "sum": 1178.765058517456, "min": 1178.765058517456}}, "EndTime": 1560450002.675564, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450001.49564}
#
# [06/13/2019 18:20:02 INFO 140082306389824] #progress_metric: host=algo-1, completed 7 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 666, "sum": 666.0, "min": 666}, "Total Records Seen": {"count": 1, "max": 664145, "sum": 664145.0, "min": 664145}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1560450002.675806, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 6}, "StartTime": 1560450001.496767}
#
# [06/13/2019 18:20:02 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=80340.3999597 records/second
# [06/13/2019 18:20:02 INFO 140082306389824] #quality_metric: host=algo-1, epoch=7, batch=0 train binary_classification_accuracy <score>=0.681
# [06/13/2019 18:20:02 INFO 140082306389824] #quality_metric: host=algo-1, epoch=7, batch=0 train binary_classification_cross_entropy <loss>=0.630260131836
# [06/13/2019 18:20:02 INFO 140082306389824] #quality_metric: host=algo-1, epoch=7, batch=0 train binary_f_1.000 <score>=0.605686032138
# [2019-06-13 18:20:03.825] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 16, "duration": 1147, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:20:03 INFO 140082306389824] #quality_metric: host=algo-1, epoch=7, train binary_classification_accuracy <score>=0.720442105263
# [06/13/2019 18:20:03 INFO 140082306389824] #quality_metric: host=algo-1, epoch=7, train binary_classification_cross_entropy <loss>=0.619931810238
# [06/13/2019 18:20:03 INFO 140082306389824] #quality_metric: host=algo-1, epoch=7, train binary_f_1.000 <score>=0.681657996308
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1150.0060558319092, "sum": 1150.0060558319092, "min": 1150.0060558319092}}, "EndTime": 1560450003.826528, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450002.675642}
#
# [06/13/2019 18:20:03 INFO 140082306389824] #progress_metric: host=algo-1, completed 8 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 761, "sum": 761.0, "min": 761}, "Total Records Seen": {"count": 1, "max": 758880, "sum": 758880.0, "min": 758880}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1560450003.826769, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 7}, "StartTime": 1560450002.676492}
#
# [06/13/2019 18:20:03 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=82349.623013 records/second
# [06/13/2019 18:20:03 INFO 140082306389824] #quality_metric: host=algo-1, epoch=8, batch=0 train binary_classification_accuracy <score>=0.694
# [06/13/2019 18:20:03 INFO 140082306389824] #quality_metric: host=algo-1, epoch=8, batch=0 train binary_classification_cross_entropy <loss>=0.623267089844
# [06/13/2019 18:20:03 INFO 140082306389824] #quality_metric: host=algo-1, epoch=8, batch=0 train binary_f_1.000 <score>=0.630434782609
# [2019-06-13 18:20:04.926] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 18, "duration": 1097, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:20:04 INFO 140082306389824] #quality_metric: host=algo-1, epoch=8, train binary_classification_accuracy <score>=0.7264
# [06/13/2019 18:20:04 INFO 140082306389824] #quality_metric: host=algo-1, epoch=8, train binary_classification_cross_entropy <loss>=0.612801652447
# [06/13/2019 18:20:04 INFO 140082306389824] #quality_metric: host=algo-1, epoch=8, train binary_f_1.000 <score>=0.69118905047
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1099.8377799987793, "sum": 1099.8377799987793, "min": 1099.8377799987793}}, "EndTime": 1560450004.927269, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450003.826604}
#
# [06/13/2019 18:20:04 INFO 140082306389824] #progress_metric: host=algo-1, completed 9 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 856, "sum": 856.0, "min": 856}, "Total Records Seen": {"count": 1, "max": 853615, "sum": 853615.0, "min": 853615}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1560450004.927581, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 8}, "StartTime": 1560450003.827396}
#
# [06/13/2019 18:20:04 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=86099.0906481 records/second
# [06/13/2019 18:20:04 INFO 140082306389824] #quality_metric: host=algo-1, epoch=9, batch=0 train binary_classification_accuracy <score>=0.697
# [06/13/2019 18:20:04 INFO 140082306389824] #quality_metric: host=algo-1, epoch=9, batch=0 train binary_classification_cross_entropy <loss>=0.616703369141
# [06/13/2019 18:20:04 INFO 140082306389824] #quality_metric: host=algo-1, epoch=9, batch=0 train binary_f_1.000 <score>=0.640569395018
# 2019-06-13 18:19:50 Training - Training image download completed. Training in progress.[2019-06-13 18:20:06.059] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 20, "duration": 1130, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:20:06 INFO 140082306389824] #quality_metric: host=algo-1, epoch=9, train binary_classification_accuracy <score>=0.731284210526
# [06/13/2019 18:20:06 INFO 140082306389824] #quality_metric: host=algo-1, epoch=9, train binary_classification_cross_entropy <loss>=0.606125123355
# [06/13/2019 18:20:06 INFO 140082306389824] #quality_metric: host=algo-1, epoch=9, train binary_f_1.000 <score>=0.698940962804
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1132.580041885376, "sum": 1132.580041885376, "min": 1132.580041885376}}, "EndTime": 1560450006.060827, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450004.927338}
#
# [06/13/2019 18:20:06 INFO 140082306389824] #progress_metric: host=algo-1, completed 10 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 951, "sum": 951.0, "min": 951}, "Total Records Seen": {"count": 1, "max": 948350, "sum": 948350.0, "min": 948350}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1560450006.06117, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 9}, "StartTime": 1560450004.928215}
#
# [06/13/2019 18:20:06 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=83608.8342178 records/second
# [06/13/2019 18:20:06 INFO 140082306389824] #quality_metric: host=algo-1, epoch=10, batch=0 train binary_classification_accuracy <score>=0.699
# [06/13/2019 18:20:06 INFO 140082306389824] #quality_metric: host=algo-1, epoch=10, batch=0 train binary_classification_cross_entropy <loss>=0.610537597656
# [06/13/2019 18:20:06 INFO 140082306389824] #quality_metric: host=algo-1, epoch=10, batch=0 train binary_f_1.000 <score>=0.647127784291
# [2019-06-13 18:20:07.141] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 22, "duration": 1078, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:20:07 INFO 140082306389824] #quality_metric: host=algo-1, epoch=10, train binary_classification_accuracy <score>=0.735694736842
# [06/13/2019 18:20:07 INFO 140082306389824] #quality_metric: host=algo-1, epoch=10, train binary_classification_cross_entropy <loss>=0.599866465358
# [06/13/2019 18:20:07 INFO 140082306389824] #quality_metric: host=algo-1, epoch=10, train binary_f_1.000 <score>=0.705614763228
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1080.1711082458496, "sum": 1080.1711082458496, "min": 1080.1711082458496}}, "EndTime": 1560450007.1421, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450006.060924}
#
# [06/13/2019 18:20:07 INFO 140082306389824] #progress_metric: host=algo-1, completed 11 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 1046, "sum": 1046.0, "min": 1046}, "Total Records Seen": {"count": 1, "max": 1043085, "sum": 1043085.0, "min": 1043085}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1560450007.142332, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 10}, "StartTime": 1560450006.061899}
#
# [06/13/2019 18:20:07 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=87668.0733747 records/second
# [06/13/2019 18:20:07 INFO 140082306389824] #quality_metric: host=algo-1, epoch=11, batch=0 train binary_classification_accuracy <score>=0.709
# [06/13/2019 18:20:07 INFO 140082306389824] #quality_metric: host=algo-1, epoch=11, batch=0 train binary_classification_cross_entropy <loss>=0.604740783691
# [06/13/2019 18:20:07 INFO 140082306389824] #quality_metric: host=algo-1, epoch=11, batch=0 train binary_f_1.000 <score>=0.664359861592
# [2019-06-13 18:20:08.334] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 24, "duration": 1190, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:20:08 INFO 140082306389824] #quality_metric: host=algo-1, epoch=11, train binary_classification_accuracy <score>=0.740221052632
# [06/13/2019 18:20:08 INFO 140082306389824] #quality_metric: host=algo-1, epoch=11, train binary_classification_cross_entropy <loss>=0.593993122944
# [06/13/2019 18:20:08 INFO 140082306389824] #quality_metric: host=algo-1, epoch=11, train binary_f_1.000 <score>=0.711892503998
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1192.4381256103516, "sum": 1192.4381256103516, "min": 1192.4381256103516}}, "EndTime": 1560450008.335478, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450007.142169}
#
# [06/13/2019 18:20:08 INFO 140082306389824] #progress_metric: host=algo-1, completed 12 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 1141, "sum": 1141.0, "min": 1141}, "Total Records Seen": {"count": 1, "max": 1137820, "sum": 1137820.0, "min": 1137820}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 13, "sum": 13.0, "min": 13}}, "EndTime": 1560450008.335871, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 11}, "StartTime": 1560450007.143008}
#
# [06/13/2019 18:20:08 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=79410.9837574 records/second
# [06/13/2019 18:20:08 INFO 140082306389824] #quality_metric: host=algo-1, epoch=12, batch=0 train binary_classification_accuracy <score>=0.71
# [06/13/2019 18:20:08 INFO 140082306389824] #quality_metric: host=algo-1, epoch=12, batch=0 train binary_classification_cross_entropy <loss>=0.599286743164
# [06/13/2019 18:20:08 INFO 140082306389824] #quality_metric: host=algo-1, epoch=12, batch=0 train binary_f_1.000 <score>=0.666666666667
# [2019-06-13 18:20:09.437] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 26, "duration": 1099, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:20:09 INFO 140082306389824] #quality_metric: host=algo-1, epoch=12, train binary_classification_accuracy <score>=0.743663157895
# [06/13/2019 18:20:09 INFO 140082306389824] #quality_metric: host=algo-1, epoch=12, train binary_classification_cross_entropy <loss>=0.588475609067
# [06/13/2019 18:20:09 INFO 140082306389824] #quality_metric: host=algo-1, epoch=12, train binary_f_1.000 <score>=0.716738397115
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1101.3519763946533, "sum": 1101.3519763946533, "min": 1101.3519763946533}}, "EndTime": 1560450009.438006, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450008.335542}
#
# [06/13/2019 18:20:09 INFO 140082306389824] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 1236, "sum": 1236.0, "min": 1236}, "Total Records Seen": {"count": 1, "max": 1232555, "sum": 1232555.0, "min": 1232555}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 14, "sum": 14.0, "min": 14}}, "EndTime": 1560450009.438252, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 12}, "StartTime": 1560450008.336624}
#
# [06/13/2019 18:20:09 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=85983.2787424 records/second
# [06/13/2019 18:20:09 INFO 140082306389824] #quality_metric: host=algo-1, epoch=13, batch=0 train binary_classification_accuracy <score>=0.714
# [06/13/2019 18:20:09 INFO 140082306389824] #quality_metric: host=algo-1, epoch=13, batch=0 train binary_classification_cross_entropy <loss>=0.594151184082
# [06/13/2019 18:20:09 INFO 140082306389824] #quality_metric: host=algo-1, epoch=13, batch=0 train binary_f_1.000 <score>=0.674259681093
# [2019-06-13 18:20:10.581] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 28, "duration": 1140, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:20:10 INFO 140082306389824] #quality_metric: host=algo-1, epoch=13, train binary_classification_accuracy <score>=0.7466
# [06/13/2019 18:20:10 INFO 140082306389824] #quality_metric: host=algo-1, epoch=13, train binary_classification_cross_entropy <loss>=0.583287214741
# [06/13/2019 18:20:10 INFO 140082306389824] #quality_metric: host=algo-1, epoch=13, train binary_f_1.000 <score>=0.720857152796
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1143.096923828125, "sum": 1143.096923828125, "min": 1143.096923828125}}, "EndTime": 1560450010.582074, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450009.438086}
#
# [06/13/2019 18:20:10 INFO 140082306389824] #progress_metric: host=algo-1, completed 14 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 1331, "sum": 1331.0, "min": 1331}, "Total Records Seen": {"count": 1, "max": 1327290, "sum": 1327290.0, "min": 1327290}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1560450010.582412, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 13}, "StartTime": 1560450009.438914}
#
# [06/13/2019 18:20:10 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=82838.4168971 records/second
# [06/13/2019 18:20:10 INFO 140082306389824] #quality_metric: host=algo-1, epoch=14, batch=0 train binary_classification_accuracy <score>=0.719
# [06/13/2019 18:20:10 INFO 140082306389824] #quality_metric: host=algo-1, epoch=14, batch=0 train binary_classification_cross_entropy <loss>=0.589312133789
# [06/13/2019 18:20:10 INFO 140082306389824] #quality_metric: host=algo-1, epoch=14, batch=0 train binary_f_1.000 <score>=0.682485875706
# [2019-06-13 18:20:11.649] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 30, "duration": 1064, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:20:11 INFO 140082306389824] #quality_metric: host=algo-1, epoch=14, train binary_classification_accuracy <score>=0.749884210526
# [06/13/2019 18:20:11 INFO 140082306389824] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy <loss>=0.578403662752
# [06/13/2019 18:20:11 INFO 140082306389824] #quality_metric: host=algo-1, epoch=14, train binary_f_1.000 <score>=0.725106146673
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1067.0881271362305, "sum": 1067.0881271362305, "min": 1067.0881271362305}}, "EndTime": 1560450011.650269, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450010.582135}
#
# [06/13/2019 18:20:11 INFO 140082306389824] #progress_metric: host=algo-1, completed 15 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 1426, "sum": 1426.0, "min": 1426}, "Total Records Seen": {"count": 1, "max": 1422025, "sum": 1422025.0, "min": 1422025}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 16, "sum": 16.0, "min": 16}}, "EndTime": 1560450011.65061, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 14}, "StartTime": 1560450010.583118}
#
# [06/13/2019 18:20:11 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=88735.9217341 records/second
# [06/13/2019 18:20:11 INFO 140082306389824] #quality_metric: host=algo-1, epoch=15, batch=0 train binary_classification_accuracy <score>=0.723
# [06/13/2019 18:20:11 INFO 140082306389824] #quality_metric: host=algo-1, epoch=15, batch=0 train binary_classification_cross_entropy <loss>=0.584749023438
# [06/13/2019 18:20:11 INFO 140082306389824] #quality_metric: host=algo-1, epoch=15, batch=0 train binary_f_1.000 <score>=0.68911335578
# [2019-06-13 18:20:12.884] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 32, "duration": 1231, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:20:12 INFO 140082306389824] #quality_metric: host=algo-1, epoch=15, train binary_classification_accuracy <score>=0.752136842105
# [06/13/2019 18:20:12 INFO 140082306389824] #quality_metric: host=algo-1, epoch=15, train binary_classification_cross_entropy <loss>=0.573802729235
# [06/13/2019 18:20:12 INFO 140082306389824] #quality_metric: host=algo-1, epoch=15, train binary_f_1.000 <score>=0.728154331036
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1233.5760593414307, "sum": 1233.5760593414307, "min": 1233.5760593414307}}, "EndTime": 1560450012.884912, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450011.65033}
#
# [06/13/2019 18:20:12 INFO 140082306389824] #progress_metric: host=algo-1, completed 16 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 1521, "sum": 1521.0, "min": 1521}, "Total Records Seen": {"count": 1, "max": 1516760, "sum": 1516760.0, "min": 1516760}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1560450012.885323, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 15}, "StartTime": 1560450011.651304}
#
# [06/13/2019 18:20:12 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=76761.6492996 records/second
# [06/13/2019 18:20:12 INFO 140082306389824] #quality_metric: host=algo-1, epoch=16, batch=0 train binary_classification_accuracy <score>=0.728
# [06/13/2019 18:20:12 INFO 140082306389824] #quality_metric: host=algo-1, epoch=16, batch=0 train binary_classification_cross_entropy <loss>=0.580442810059
# [06/13/2019 18:20:12 INFO 140082306389824] #quality_metric: host=algo-1, epoch=16, batch=0 train binary_f_1.000 <score>=0.69710467706
# [2019-06-13 18:20:13.965] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 34, "duration": 1078, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:20:13 INFO 140082306389824] #quality_metric: host=algo-1, epoch=16, train binary_classification_accuracy <score>=0.754715789474
# [06/13/2019 18:20:13 INFO 140082306389824] #quality_metric: host=algo-1, epoch=16, train binary_classification_cross_entropy <loss>=0.569463963559
# [06/13/2019 18:20:13 INFO 140082306389824] #quality_metric: host=algo-1, epoch=16, train binary_f_1.000 <score>=0.73161798581
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1080.1379680633545, "sum": 1080.1379680633545, "min": 1080.1379680633545}}, "EndTime": 1560450013.966221, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450012.885015}
#
# [06/13/2019 18:20:13 INFO 140082306389824] #progress_metric: host=algo-1, completed 17 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 1616, "sum": 1616.0, "min": 1616}, "Total Records Seen": {"count": 1, "max": 1611495, "sum": 1611495.0, "min": 1611495}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 18, "sum": 18.0, "min": 18}}, "EndTime": 1560450013.966505, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 16}, "StartTime": 1560450012.886036}
#
# [06/13/2019 18:20:13 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=87670.5879716 records/second
# [06/13/2019 18:20:13 INFO 140082306389824] #quality_metric: host=algo-1, epoch=17, batch=0 train binary_classification_accuracy <score>=0.73
# [06/13/2019 18:20:13 INFO 140082306389824] #quality_metric: host=algo-1, epoch=17, batch=0 train binary_classification_cross_entropy <loss>=0.576375488281
# [06/13/2019 18:20:13 INFO 140082306389824] #quality_metric: host=algo-1, epoch=17, batch=0 train binary_f_1.000 <score>=0.70066518847
# [2019-06-13 18:20:15.123] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 1155, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:20:15 INFO 140082306389824] #quality_metric: host=algo-1, epoch=17, train binary_classification_accuracy <score>=0.757031578947
# [06/13/2019 18:20:15 INFO 140082306389824] #quality_metric: host=algo-1, epoch=17, train binary_classification_cross_entropy <loss>=0.565368446109
# [06/13/2019 18:20:15 INFO 140082306389824] #quality_metric: host=algo-1, epoch=17, train binary_f_1.000 <score>=0.734604240445
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1157.608985900879, "sum": 1157.608985900879, "min": 1157.608985900879}}, "EndTime": 1560450015.124784, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450013.966291}
#
# [06/13/2019 18:20:15 INFO 140082306389824] #progress_metric: host=algo-1, completed 18 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 1711, "sum": 1711.0, "min": 1711}, "Total Records Seen": {"count": 1, "max": 1706230, "sum": 1706230.0, "min": 1706230}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 19, "sum": 19.0, "min": 19}}, "EndTime": 1560450015.125055, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 17}, "StartTime": 1560450013.967146}
#
# [06/13/2019 18:20:15 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=81807.7394192 records/second
# [06/13/2019 18:20:15 INFO 140082306389824] #quality_metric: host=algo-1, epoch=18, batch=0 train binary_classification_accuracy <score>=0.734
# [06/13/2019 18:20:15 INFO 140082306389824] #quality_metric: host=algo-1, epoch=18, batch=0 train binary_classification_cross_entropy <loss>=0.572530151367
# [06/13/2019 18:20:15 INFO 140082306389824] #quality_metric: host=algo-1, epoch=18, batch=0 train binary_f_1.000 <score>=0.708333333333
# [2019-06-13 18:20:16.218] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 1091, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:20:16 INFO 140082306389824] #quality_metric: host=algo-1, epoch=18, train binary_classification_accuracy <score>=0.758336842105
# [06/13/2019 18:20:16 INFO 140082306389824] #quality_metric: host=algo-1, epoch=18, train binary_classification_cross_entropy <loss>=0.561498596191
# ...
#
# [06/13/2019 18:21:41 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=87451.8366745 records/second
# [06/13/2019 18:21:41 INFO 140082306389824] #quality_metric: host=algo-1, epoch=95, batch=0 train binary_classification_accuracy <score>=0.782
# [06/13/2019 18:21:41 INFO 140082306389824] #quality_metric: host=algo-1, epoch=95, batch=0 train binary_classification_cross_entropy <loss>=0.46113180542
# [06/13/2019 18:21:41 INFO 140082306389824] #quality_metric: host=algo-1, epoch=95, batch=0 train binary_f_1.000 <score>=0.778904665314
# [2019-06-13 18:21:42.311] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 192, "duration": 1106, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:21:42 INFO 140082306389824] #quality_metric: host=algo-1, epoch=95, train binary_classification_accuracy <score>=0.796578947368
# [06/13/2019 18:21:42 INFO 140082306389824] #quality_metric: host=algo-1, epoch=95, train binary_classification_cross_entropy <loss>=0.453880237459
# [06/13/2019 18:21:42 INFO 140082306389824] #quality_metric: host=algo-1, epoch=95, train binary_f_1.000 <score>=0.785432743019
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1108.7138652801514, "sum": 1108.7138652801514, "min": 1108.7138652801514}}, "EndTime": 1560450102.312467, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450101.202805}
#
# [06/13/2019 18:21:42 INFO 140082306389824] #progress_metric: host=algo-1, completed 96 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 9121, "sum": 9121.0, "min": 9121}, "Total Records Seen": {"count": 1, "max": 9095560, "sum": 9095560.0, "min": 9095560}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 97, "sum": 97.0, "min": 97}}, "EndTime": 1560450102.312744, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 95}, "StartTime": 1560450101.203724}
#
# [06/13/2019 18:21:42 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=85413.1023593 records/second
# [06/13/2019 18:21:42 INFO 140082306389824] #quality_metric: host=algo-1, epoch=96, batch=0 train binary_classification_accuracy <score>=0.783
# [06/13/2019 18:21:42 INFO 140082306389824] #quality_metric: host=algo-1, epoch=96, batch=0 train binary_classification_cross_entropy <loss>=0.460302276611
# [06/13/2019 18:21:42 INFO 140082306389824] #quality_metric: host=algo-1, epoch=96, batch=0 train binary_f_1.000 <score>=0.780141843972
# [2019-06-13 18:21:43.385] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 194, "duration": 1070, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:21:43 INFO 140082306389824] #quality_metric: host=algo-1, epoch=96, train binary_classification_accuracy <score>=0.796852631579
# [06/13/2019 18:21:43 INFO 140082306389824] #quality_metric: host=algo-1, epoch=96, train binary_classification_cross_entropy <loss>=0.453102431448
# [06/13/2019 18:21:43 INFO 140082306389824] #quality_metric: host=algo-1, epoch=96, train binary_f_1.000 <score>=0.78579752933
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1072.7460384368896, "sum": 1072.7460384368896, "min": 1072.7460384368896}}, "EndTime": 1560450103.386223, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450102.312538}
#
# [06/13/2019 18:21:43 INFO 140082306389824] #progress_metric: host=algo-1, completed 97 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 9216, "sum": 9216.0, "min": 9216}, "Total Records Seen": {"count": 1, "max": 9190295, "sum": 9190295.0, "min": 9190295}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 98, "sum": 98.0, "min": 98}}, "EndTime": 1560450103.386515, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 96}, "StartTime": 1560450102.313447}
#
# [06/13/2019 18:21:43 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=88273.8792998 records/second
# [06/13/2019 18:21:43 INFO 140082306389824] #quality_metric: host=algo-1, epoch=97, batch=0 train binary_classification_accuracy <score>=0.784
# [06/13/2019 18:21:43 INFO 140082306389824] #quality_metric: host=algo-1, epoch=97, batch=0 train binary_classification_cross_entropy <loss>=0.459476715088
# [06/13/2019 18:21:43 INFO 140082306389824] #quality_metric: host=algo-1, epoch=97, batch=0 train binary_f_1.000 <score>=0.781376518219
# [2019-06-13 18:21:44.537] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 196, "duration": 1149, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:21:44 INFO 140082306389824] #quality_metric: host=algo-1, epoch=97, train binary_classification_accuracy <score>=0.797252631579
# [06/13/2019 18:21:44 INFO 140082306389824] #quality_metric: host=algo-1, epoch=97, train binary_classification_cross_entropy <loss>=0.45232770964
# [06/13/2019 18:21:44 INFO 140082306389824] #quality_metric: host=algo-1, epoch=97, train binary_f_1.000 <score>=0.786247766594
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1151.2830257415771, "sum": 1151.2830257415771, "min": 1151.2830257415771}}, "EndTime": 1560450104.538496, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450103.386304}
#
# [06/13/2019 18:21:44 INFO 140082306389824] #progress_metric: host=algo-1, completed 98 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 9311, "sum": 9311.0, "min": 9311}, "Total Records Seen": {"count": 1, "max": 9285030, "sum": 9285030.0, "min": 9285030}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 99, "sum": 99.0, "min": 99}}, "EndTime": 1560450104.538734, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 97}, "StartTime": 1560450103.387182}
#
# [06/13/2019 18:21:44 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=82258.6039194 records/second
# [06/13/2019 18:21:44 INFO 140082306389824] #quality_metric: host=algo-1, epoch=98, batch=0 train binary_classification_accuracy <score>=0.784
# [06/13/2019 18:21:44 INFO 140082306389824] #quality_metric: host=algo-1, epoch=98, batch=0 train binary_classification_cross_entropy <loss>=0.458654968262
# [06/13/2019 18:21:44 INFO 140082306389824] #quality_metric: host=algo-1, epoch=98, batch=0 train binary_f_1.000 <score>=0.781376518219
# [2019-06-13 18:21:45.638] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 198, "duration": 1097, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:21:45 INFO 140082306389824] #quality_metric: host=algo-1, epoch=98, train binary_classification_accuracy <score>=0.797526315789
# [06/13/2019 18:21:45 INFO 140082306389824] #quality_metric: host=algo-1, epoch=98, train binary_classification_cross_entropy <loss>=0.451555922016
# [06/13/2019 18:21:45 INFO 140082306389824] #quality_metric: host=algo-1, epoch=98, train binary_f_1.000 <score>=0.786588410203
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1099.8461246490479, "sum": 1099.8461246490479, "min": 1099.8461246490479}}, "EndTime": 1560450105.639307, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450104.53857}
#
# [06/13/2019 18:21:45 INFO 140082306389824] #progress_metric: host=algo-1, completed 99 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 9406, "sum": 9406.0, "min": 9406}, "Total Records Seen": {"count": 1, "max": 9379765, "sum": 9379765.0, "min": 9379765}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 100, "sum": 100.0, "min": 100}}, "EndTime": 1560450105.639627, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 98}, "StartTime": 1560450104.539393}
#
# [06/13/2019 18:21:45 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=86095.7326354 records/second
# [06/13/2019 18:21:45 INFO 140082306389824] #quality_metric: host=algo-1, epoch=99, batch=0 train binary_classification_accuracy <score>=0.784
# [06/13/2019 18:21:45 INFO 140082306389824] #quality_metric: host=algo-1, epoch=99, batch=0 train binary_classification_cross_entropy <loss>=0.45783694458
# [06/13/2019 18:21:45 INFO 140082306389824] #quality_metric: host=algo-1, epoch=99, batch=0 train binary_f_1.000 <score>=0.781376518219
# [2019-06-13 18:21:46.765] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 200, "duration": 1124, "num_examples": 95, "num_bytes": 6063040}
# [06/13/2019 18:21:46 INFO 140082306389824] #quality_metric: host=algo-1, epoch=99, train binary_classification_accuracy <score>=0.797894736842
# [06/13/2019 18:21:46 INFO 140082306389824] #quality_metric: host=algo-1, epoch=99, train binary_classification_cross_entropy <loss>=0.450786918239
# [06/13/2019 18:21:46 INFO 140082306389824] #quality_metric: host=algo-1, epoch=99, train binary_f_1.000 <score>=0.787002729028
# [06/13/2019 18:21:46 INFO 140082306389824] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.797894736842
# [06/13/2019 18:21:46 INFO 140082306389824] #quality_metric: host=algo-1, train binary_classification_cross_entropy <loss>=0.450786918239
# [06/13/2019 18:21:46 INFO 140082306389824] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.787002729028
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1126.6489028930664, "sum": 1126.6489028930664, "min": 1126.6489028930664}}, "EndTime": 1560450106.767008, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450105.639374}
#
# [06/13/2019 18:21:46 INFO 140082306389824] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Batches Since Last Reset": {"count": 1, "max": 95, "sum": 95.0, "min": 95}, "Number of Records Since Last Reset": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Total Batches Seen": {"count": 1, "max": 9501, "sum": 9501.0, "min": 9501}, "Total Records Seen": {"count": 1, "max": 9474500, "sum": 9474500.0, "min": 9474500}, "Max Records Seen Between Resets": {"count": 1, "max": 94735, "sum": 94735.0, "min": 94735}, "Reset Count": {"count": 1, "max": 101, "sum": 101.0, "min": 101}}, "EndTime": 1560450106.767333, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 99}, "StartTime": 1560450105.640329}
#
# [06/13/2019 18:21:46 INFO 140082306389824] #throughput_metric: host=algo-1, train throughput=84051.2457773 records/second
# [06/13/2019 18:21:46 WARNING 140082306389824] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [06/13/2019 18:21:46 INFO 140082306389824] Pulling entire model from kvstore to finalize
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 25.441884994506836, "sum": 25.441884994506836, "min": 25.441884994506836}}, "EndTime": 1560450106.793153, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450106.767096}
# [06/13/2019 18:21:46 INFO 140082306389824] Saved checkpoint to "/tmp/tmpbCLoBq/state-0001.params"
# [2019-06-13 18:21:47.105] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 114151, "num_examples": 1, "num_bytes": 64000}
# [2019-06-13 18:21:47.656] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 550, "num_examples": 7, "num_bytes": 390336}
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 7, "sum": 7.0, "min": 7}, "Number of Batches Since Last Reset": {"count": 1, "max": 7, "sum": 7.0, "min": 7}, "Number of Records Since Last Reset": {"count": 1, "max": 6099, "sum": 6099.0, "min": 6099}, "Total Batches Seen": {"count": 1, "max": 7, "sum": 7.0, "min": 7}, "Total Records Seen": {"count": 1, "max": 6099, "sum": 6099.0, "min": 6099}, "Max Records Seen Between Resets": {"count": 1, "max": 6099, "sum": 6099.0, "min": 6099}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1560450107.656536, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450107.105155}
#
# [06/13/2019 18:21:47 INFO 140082306389824] #test_score (algo-1) : ('binary_classification_accuracy', 0.67437284800787012)
# [06/13/2019 18:21:47 INFO 140082306389824] #test_score (algo-1) : ('binary_classification_cross_entropy', 0.59619279540275072)
# [06/13/2019 18:21:47 INFO 140082306389824] #test_score (algo-1) : ('binary_f_1.000', 0.6982680036463081)
# [06/13/2019 18:21:47 INFO 140082306389824] #quality_metric: host=algo-1, test binary_classification_accuracy <score>=0.674372848008
# [06/13/2019 18:21:47 INFO 140082306389824] #quality_metric: host=algo-1, test binary_classification_cross_entropy <loss>=0.596192795403
# [06/13/2019 18:21:47 INFO 140082306389824] #quality_metric: host=algo-1, test binary_f_1.000 <score>=0.698268003646
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 114773.68092536926, "sum": 114773.68092536926, "min": 114773.68092536926}, "setuptime": {"count": 1, "max": 56.07295036315918, "sum": 56.07295036315918, "min": 56.07295036315918}}, "EndTime": 1560450107.65794, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1560450106.793545}
#
#
# 2019-06-13 18:22:01 Completed - Training job completed
# Billable seconds: 179

# %% [markdown]
# ## Part 2 - Repackaging Model data to fit a KNN Model
#
# Now that we have the model created and stored in SageMaker, we can download the same and repackage it to fit a KNN model.

# %% [markdown]
# ### Download model data

# %%
import mxnet as mx
model_file_name = "model.tar.gz"
model_full_path = fm.output_path +"/"+ fm.latest_training_job.job_name +"/output/"+model_file_name
print "Model Path: ", model_full_path

#Download FM model 
# %cd ..
os.system('aws s3 cp '+model_full_path+ ' ./')

#Extract model file for loading to MXNet
os.system('tar xzvf '+model_file_name)
os.system("unzip -o model_algo-1")
os.system("mv symbol.json model-symbol.json")
os.system("mv params model-0000.params")
# Out:
# Model Path:  s3://movie-recommender-josh-krishna/fm/output/factorization-machines-2019-06-13-18-16-18-700/output/model.tar.gz
# /home/ec2-user/SageMaker/MovieRecommender/Notebook
# 0

# %% [markdown]
# ### Extract model data to create item and user latent matrixes

# %%
#Extract model data
m = mx.module.Module.load('./model', 0, False, label_names=['out_label'])
V = m._arg_params['v'].asnumpy()
w = m._arg_params['w1_weight'].asnumpy()
b = m._arg_params['w0_weight'].asnumpy()

# item latent matrix - concat(V[i], w[i]).  
knn_item_matrix = np.concatenate((V[nb_users:], w[nb_users:]), axis=1)
knn_train_label = np.arange(1,nb_movies+1)

#user latent matrix - concat (V[u], 1) 
ones = np.ones(nb_users).reshape((nb_users, 1))
knn_user_matrix = np.concatenate((V[:nb_users], ones), axis=1)

# %% [markdown]
# ## Part 3 - Building KNN Model
#
# In this section, we upload the model input data to S3, create a KNN model and save the same. Saving the model, will display the model in the model section of SageMaker. Also, it will aid in calling batch transform down the line or even deploying it as an end point for real-time inference.
#
# This approach uses the default 'index_type' parameter for knn. It is precise but can be slow for large datasets. In such cases, you may want to use a different 'index_type' parameter leading to an approximate, yet fast answer.

# %%
print('KNN train features shape = ', knn_item_matrix.shape)
knn_prefix = 'knn'
knn_output_prefix  = 's3://{}/{}/output'.format(bucket, knn_prefix)
knn_train_data_path = writeDatasetToProtobuf(knn_item_matrix, bucket, knn_prefix, train_key, "dense", knn_train_label)
print('uploaded KNN train data: {}'.format(knn_train_data_path))

nb_recommendations = 5

# set up the estimator
knn = sagemaker.estimator.Estimator(get_image_uri(boto3.Session().region_name, "knn"),
    get_execution_role(),
    train_instance_count=1,
    train_instance_type=instance_type,
    output_path=knn_output_prefix,
    sagemaker_session=sagemaker.Session())

knn.set_hyperparameters(feature_dim=knn_item_matrix.shape[1], k=nb_recommendations, index_metric="INNER_PRODUCT", predictor_type='classifier', sample_size=200000)
fit_input = {'train': knn_train_data_path}
knn.fit(fit_input)
knn_model_name =  knn.latest_training_job.job_name
print "created model: ", knn_model_name

# save the model so that we can reference it in the next step during batch inference
sm = boto3.client(service_name='sagemaker')
primary_container = {
    'Image': knn.image_name,
    'ModelDataUrl': knn.model_data,
}

knn_model = sm.create_model(
        ModelName = knn.latest_training_job.job_name,
        ExecutionRoleArn = knn.role,
        PrimaryContainer = primary_container)
print "saved the model"
# Out:
# ('KNN train features shape = ', (193609, 65))
# uploaded KNN train data: s3://movie-recommender-josh-krishna/knn/train.protobuf
# 2019-06-13 18:22:45 Starting - Starting the training job...
# 2019-06-13 18:22:46 Starting - Launching requested ML instances......
# 2019-06-13 18:23:53 Starting - Preparing the instances for training...
# 2019-06-13 18:24:43 Downloading - Downloading input data......
# 2019-06-13 18:25:45 Training - Training image download completed. Training in progress.
# 2019-06-13 18:25:45 Uploading - Uploading generated training model.
# Docker entrypoint called with argument(s): train
# [06/13/2019 18:25:41 INFO 140666129676096] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'index_metric': u'L2', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'_log_level': u'info', u'faiss_index_ivf_nlists': u'auto', u'epochs': u'1', u'index_type': u'faiss.Flat', u'_faiss_index_nprobe': u'5', u'_kvstore': u'dist_async', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000'}
# [06/13/2019 18:25:41 INFO 140666129676096] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'sample_size': u'200000', u'feature_dim': u'65', u'index_metric': u'INNER_PRODUCT', u'k': u'5', u'predictor_type': u'classifier'}
# [06/13/2019 18:25:41 INFO 140666129676096] Final configuration: {u'index_metric': u'INNER_PRODUCT', u'predictor_type': u'classifier', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'_log_level': u'info', u'feature_dim': u'65', u'faiss_index_ivf_nlists': u'auto', u'sample_size': u'200000', u'epochs': u'1', u'index_type': u'faiss.Flat', u'_faiss_index_nprobe': u'5', u'_kvstore': u'dist_async', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'k': u'5'}
# [06/13/2019 18:25:41 WARNING 140666129676096] Loggers have already been setup.
# [06/13/2019 18:25:41 INFO 140666129676096] Launching parameter server for role scheduler
# [06/13/2019 18:25:41 INFO 140666129676096] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/cadb2101-b0b7-4c09-8cc3-f721bf4e39ad', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'knn-2019-06-13-18-22-45-208', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '1', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/b2b3d8b4-8f23-4cd2-adb3-6b52769fc511', 'PWD': '/', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [06/13/2019 18:25:41 INFO 140666129676096] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/cadb2101-b0b7-4c09-8cc3-f721bf4e39ad', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.32.0.4', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'knn-2019-06-13-18-22-45-208', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '1', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/b2b3d8b4-8f23-4cd2-adb3-6b52769fc511', 'DMLC_ROLE': 'scheduler', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [06/13/2019 18:25:41 INFO 140666129676096] Launching parameter server for role server
# [06/13/2019 18:25:41 INFO 140666129676096] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/cadb2101-b0b7-4c09-8cc3-f721bf4e39ad', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'knn-2019-06-13-18-22-45-208', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '1', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/b2b3d8b4-8f23-4cd2-adb3-6b52769fc511', 'PWD': '/', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [06/13/2019 18:25:41 INFO 140666129676096] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/cadb2101-b0b7-4c09-8cc3-f721bf4e39ad', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.32.0.4', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'knn-2019-06-13-18-22-45-208', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '1', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/b2b3d8b4-8f23-4cd2-adb3-6b52769fc511', 'DMLC_ROLE': 'server', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [06/13/2019 18:25:41 INFO 140666129676096] Environment: {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/cadb2101-b0b7-4c09-8cc3-f721bf4e39ad', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '1', 'SAGEMAKER_HTTP_PORT': '8080', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.32.0.4', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'knn-2019-06-13-18-22-45-208', 'HOME': '/root', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '1', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/b2b3d8b4-8f23-4cd2-adb3-6b52769fc511', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# Process 33 is a shell:scheduler.
# Process 34 is a shell:server.
# Process 1 is a worker.
# [06/13/2019 18:25:41 INFO 140666129676096] Using default worker.
# [2019-06-13 18:25:42.197] [tensorio] [info] batch={"data_pipeline": "/opt/ml/input/data/train", "num_examples": 5000, "features": [{"name": "label_values", "shape": [1], "storage_type": "dense"}, {"name": "values", "shape": [65], "storage_type": "dense"}]}
# [06/13/2019 18:25:42 INFO 140666129676096] nvidia-smi took: 0.0251607894897 secs to identify 0 gpus
# [06/13/2019 18:25:42 INFO 140666129676096] Create Store: dist_async
# [06/13/2019 18:25:43 ERROR 140666129676096] nvidia-smi: failed to run (127): /bin/sh: nvidia-smi: command not found
# [06/13/2019 18:25:43 INFO 140666129676096] Using per-worker sample size = 200000 (Available virtual memory = 6418374656 bytes, GPU free memory = 0 bytes, number of workers = 1). If an out-of-memory error occurs, choose a larger instance type, use dimension reduction, decrease sample_size, and/or decrease mini_batch_size.
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1560450343.798147, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/KNN"}, "StartTime": 1560450343.798107}
#
# [2019-06-13 18:25:43.800] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 0, "duration": 1618, "num_examples": 1}
# [06/13/2019 18:25:44 INFO 140666129676096] push reservoir to kv... 1 num_workers 0 rank
# [06/13/2019 18:25:44 INFO 140666129676096] ...done (193609)
# [06/13/2019 18:25:44 INFO 140666129676096] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 39, "sum": 39.0, "min": 39}, "Number of Batches Since Last Reset": {"count": 1, "max": 39, "sum": 39.0, "min": 39}, "Number of Records Since Last Reset": {"count": 1, "max": 193609, "sum": 193609.0, "min": 193609}, "Total Batches Seen": {"count": 1, "max": 39, "sum": 39.0, "min": 39}, "Total Records Seen": {"count": 1, "max": 193609, "sum": 193609.0, "min": 193609}, "Max Records Seen Between Resets": {"count": 1, "max": 193609, "sum": 193609.0, "min": 193609}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1560450344.319242, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KNN", "epoch": 0}, "StartTime": 1560450343.801097}
#
# [06/13/2019 18:25:44 INFO 140666129676096] #throughput_metric: host=algo-1, train throughput=373544.793422 records/second
# [06/13/2019 18:25:44 INFO 140666129676096] pulled row count... worker 0 rows 193609
# [06/13/2019 18:25:44 INFO 140666129676096] pulled... worker 0 data (193609, 65) labels (193609, 1) nans 0
# [06/13/2019 18:25:44 INFO 140666129676096] calling index.train...
# [06/13/2019 18:25:44 INFO 140666129676096] ...done calling index.train
# [06/13/2019 18:25:44 INFO 140666129676096] calling index.add...
# [06/13/2019 18:25:44 INFO 140666129676096] ...done calling index.add
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "model.serialize.time": {"count": 1, "max": 28.245925903320312, "sum": 28.245925903320312, "min": 28.245925903320312}, "finalize.time": {"count": 1, "max": 313.19212913513184, "sum": 313.19212913513184, "min": 313.19212913513184}, "initialize.time": {"count": 1, "max": 1542.1302318572998, "sum": 1542.1302318572998, "min": 1542.1302318572998}, "update.time": {"count": 1, "max": 517.8148746490479, "sum": 517.8148746490479, "min": 517.8148746490479}}, "EndTime": 1560450344.661084, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KNN"}, "StartTime": 1560450342.181717}
#
# [06/13/2019 18:25:44 INFO 140666129676096] Test data is not provided.
# [2019-06-13 18:25:44.661] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 1, "duration": 860, "num_examples": 39}
# [2019-06-13 18:25:44.661] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "duration": 2478, "num_epochs": 2, "num_examples": 40}
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 2974.048137664795, "sum": 2974.048137664795, "min": 2974.048137664795}, "setuptime": {"count": 1, "max": 34.64198112487793, "sum": 34.64198112487793, "min": 34.64198112487793}}, "EndTime": 1560450344.665508, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KNN"}, "StartTime": 1560450344.661165}
# 2019-06-13 18:25:58 Completed - Training job completed
# Billable seconds: 75
# created model:  knn-2019-06-13-18-22-45-208
# saved the model

# %% [markdown]
# ## Part 4 - Batch Transform
#
# In this section, we will use SageMaker's batch transform option to batch predict top X for all the users.

# %%
#upload inference data to S3
knn_batch_data_path = writeDatasetToProtobuf(knn_user_matrix, bucket, knn_prefix, train_key, "dense")
print "Batch inference data path: ",knn_batch_data_path

# Initialize the transformer object
transformer =sagemaker.transformer.Transformer(
    base_transform_job_name="knn",
    model_name=knn_model_name,
    instance_count=1,
    instance_type=instance_type,
    output_path=knn_output_prefix,
    accept="application/jsonlines; verbose=true"
)

# Start a transform job:
transformer.transform(knn_batch_data_path, content_type='application/x-recordio-protobuf')
transformer.wait()


#Download predictions 
results_file_name = "inference_output"
inference_output_file = "knn/output/train.protobuf.out"
s3_client = boto3.client('s3')
s3_client.download_file(bucket, inference_output_file, results_file_name)
with open(results_file_name) as f:
    results = f.readlines()
# Out:
# Batch inference data path:  s3://movie-recommender-josh-krishna/knn/train.protobuf
# .........................................!

# %%
import json
test_user_idx = 4
u_one_json = json.loads(results[test_user_idx])

movies_df = pd.read_csv("./ml-latest-small/movies.csv")

#print user_movie_ratings_train[user_movie_ratings_train.user_id==int(test_user_idx)].movie_id

print "Recommended movie Ids for user #{} : {}".format(test_user_idx+1, [movies_df[movies_df.movieId==int(movie_id)].title.item() for movie_id in u_one_json['labels']])
print
print "Movie distances for user #{} : {}".format(test_user_idx+1,  [round(distance, 4) for distance in u_one_json['distances']])
# Out:
# Recommended movie Ids for user #5 : ['Cove, The (2009)', 'Shawshank Redemption, The (1994)', 'Godfather, The (1972)', 'Incendies (2010)', 'Hunt, The (Jagten) (2012)']
#
# Movie distances for user #5 : [0.5693, 0.5709, 0.6057, 0.6203, 0.6301]

# %%
# %pwd
# Out:
# u'/home/ec2-user/SageMaker/MovieRecommender/Notebook'
